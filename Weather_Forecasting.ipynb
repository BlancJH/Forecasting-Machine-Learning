# %% [markdown]
# <a href="https://colab.research.google.com/github/BlancJH/Forecasting-Machine-Learning/blob/main/Weather_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %%
# Import modules
import pandas as pd

# %%
# Load datasets
file_path_asos = r'/ASOS_DATA.csv'
asos = pd.read_csv(file_path_asos)

file_path_geo = r'/GEO_DATA.csv'
geo = pd.read_csv(file_path_geo, encoding='euc-kr')

# %%
# Replacing Korean Region names to English alphabet
geo['STN_KO'] = geo['STN_KO'].str.replace('철원', 'Cheol_Won')
geo['STN_KO'] = geo['STN_KO'].str.replace('춘천', 'Choon_Cheon')
geo['STN_KO'] = geo['STN_KO'].str.replace('북강릉', 'Buk_Gang_Reung')
geo['STN_KO'] = geo['STN_KO'].str.replace('강릉', 'Gang_Reung')
geo['STN_KO'] = geo['STN_KO'].str.replace('서울', 'Seoul')
geo['STN_KO'] = geo['STN_KO'].str.replace('인천', 'Incheon')
geo['STN_KO'] = geo['STN_KO'].str.replace('울릉도', 'Ul_Reung_Do')
geo['STN_KO'] = geo['STN_KO'].str.replace('수원', 'Suwon')
geo['STN_KO'] = geo['STN_KO'].str.replace('서산', 'Seo_San')
geo['STN_KO'] = geo['STN_KO'].str.replace('청주', 'Cheong_Ju')
geo['STN_KO'] = geo['STN_KO'].str.replace('대전', 'Dae_Jeon')
geo['STN_KO'] = geo['STN_KO'].str.replace('안동', 'Ahn_Dong')
geo['STN_KO'] = geo['STN_KO'].str.replace('전주', 'Jeon_Ju')
geo['STN_KO'] = geo['STN_KO'].str.replace('부산', 'Busan')
geo['STN_KO'] = geo['STN_KO'].str.replace('목포', 'Mok_Po')
geo['STN_KO'] = geo['STN_KO'].str.replace('여수', 'Yeo_Su')
geo['STN_KO'] = geo['STN_KO'].str.replace('제주', 'Jeju')

# %%
geo
# Out:
#     STN_ID             TM_ED             TM_ST          STN_KO    STN_SP  \
# 0       95  2015.07.13.00:00  1998.12.22.17:00       Cheol_Won  41111211
# 1      101  2100.12.31.00:00  2013.08.01.14:28     Choon_Cheon  41211111
# 2      104  2100.12.31.00:00  2008.07.01.00:00  Buk_Gang_Reung  41111111
# 3      105  2100.12.31.00:00  2005.01.01.00:00      Gang_Reung  41111111
# 4      108  2100.12.31.00:00  2010.08.16.00:00           Seoul  41111111
# 5      112  2100.12.31.00:00  2012.06.01.11:10         Incheon  41211111
# 6      115  2015.07.13.00:00  1999.03.29.16:00     Ul_Reung_Do  41111211
# 7      119  2013.08.01.13:10  1998.12.28.18:00           Suwon  41111000
# 8      129  2100.12.31.00:00  2012.06.01.11:20         Seo_San  41211111
# 9      131  2100.12.31.00:00  1998.12.24.14:00       Cheong_Ju  41111111
# 10     133  2100.12.31.00:00  2012.06.01.10:30        Dae_Jeon  41211111
# 11     136  2100.12.31.00:00  1998.12.24.17:00        Ahn_Dong  41111111
# ...
